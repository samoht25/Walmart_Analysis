# %%
run src/preprocessing.ipynb
# Out:
# /home/jovyan
# /home/jovyan/Walmart_Project

# %%
import scipy.stats as st
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 10 columns):
# Size            421570 non-null int64
# Temperature     421570 non-null float64
# Fuel_Price      421570 non-null float64
# MarkDown1       421570 non-null float64
# MarkDown2       421570 non-null float64
# MarkDown3       421570 non-null float64
# MarkDown4       421570 non-null float64
# MarkDown5       421570 non-null float64
# CPI             421570 non-null float64
# Unemployment    421570 non-null float64
# dtypes: float64(9), int64(1)
# memory usage: 32.2 MB

# %% [markdown]
# ### Observing the distribution plots on several of these features:

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Size"], ax=ax[0])
sns.distplot(numeric_test_df["Size"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Fuel_Price"], ax=ax[0])
sns.distplot(numeric_test_df["Fuel_Price"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown1"], ax=ax[0])
sns.distplot(numeric_test_df["MarkDown1"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown2"], ax=ax[0])
sns.distplot(numeric_test_df["MarkDown2"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown3"], ax=ax[0])
sns.distplot(numeric_test_df["MarkDown3"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown4"], ax=ax[0])
sns.distplot(numeric_test_df["MarkDown4"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown5"], ax=ax[0])
sns.distplot(numeric_test_df["MarkDown5"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["CPI"], ax=ax[0])
sns.distplot(numeric_test_df["CPI"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Unemployment"], ax=ax[0])
sns.distplot(numeric_test_df["Unemployment"], ax =ax[1])

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
#Plot of median, medium, std.
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Temperature"], ax=ax[0])
sns.distplot(numeric_test_df["Temperature"], ax =ax[1])
ax[0].axvline(numeric_train_df["Temperature"].mean(), color="black", lw=3, label="mean")
ax[1].axvline(numeric_test_df["Temperature"].mean(), color="black", lw=3, label="mean")
ax[0].axvline(numeric_train_df["Temperature"].median(), color="blue", lw=3, ls="dashed", label="median")
ax[1].axvline(numeric_test_df["Temperature"].median(), color="blue", lw=3, ls="dashed", label= "median")
ax[0].axvline(numeric_train_df["Temperature"].mean() - train_df["Temperature"].std(), color="red", lw=3, label="std")
ax[0].axvline(numeric_train_df["Temperature"].mean() + train_df["Temperature"].std(), color="red", lw=3, label="std")
ax[1].axvline(numeric_test_df["Temperature"].mean() - test_df["Temperature"].std(), color="red", lw=3, label="std")
ax[1].axvline(numeric_test_df["Temperature"].mean() + test_df["Temperature"].std(), color="red", lw=3, label="std")
plt.legend()

ax[0].set_title("Train")
ax[1].set_title("Test")
# Out:
# Text(0.5,1,'Test')

# %% [markdown]
# ### Taking a small sample out of the dataset to look at the Z-Score. The Z-score is how many standard deviation each data point is away from the mean.

# %%
numeric_train_sample = numeric_train_df.sample(4)
numeric_train_sample_z_scores = (numeric_train_sample - numeric_train_sample.mean()) / (numeric_train_sample.mean())
numeric_train_sample_z_scores.head()
# Out:
#             Size  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 86758  -0.202438    -0.502350   -0.063683  -0.470079  -0.932658   2.673504
# 177340  0.096422    -0.394059    0.020859   1.470011   1.894785  -0.999776
# 16386   0.082771     0.456853    0.045448  -0.309641   0.007273  -0.677202
# 148821  0.023245     0.439556   -0.002625  -0.690291  -0.969401  -0.996526
#
#         MarkDown4  MarkDown5       CPI  Unemployment
# 86758   -0.439622   1.255684 -0.155176     -0.105448
# 177340   1.133283  -0.202073  0.387631     -0.058943
# 16386   -0.176904  -0.410319 -0.157879      0.116263
# 148821  -0.516757  -0.643292 -0.074577      0.048128

# %%
numeric_train_sample_z_scores.plot(kind="bar", figsize=(20,10))
labels = ["Sample {}".format(i) for i in numeric_train_sample_z_scores.index]
plt.xticks(range(4), labels);

# %% [markdown]
# ### We will want to make the features more normally distributed. Creating Log and BoxCox to normalize the Data

# %%
numeric_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 10 columns):
# Size            421570 non-null int64
# Temperature     421570 non-null float64
# Fuel_Price      421570 non-null float64
# MarkDown1       421570 non-null float64
# MarkDown2       421570 non-null float64
# MarkDown3       421570 non-null float64
# MarkDown4       421570 non-null float64
# MarkDown5       421570 non-null float64
# CPI             421570 non-null float64
# Unemployment    421570 non-null float64
# dtypes: float64(9), int64(1)
# memory usage: 32.2 MB

# %%
(np.abs(numeric_train_df.min().min()))
# -265.760
# Out:
# 265.75999999999999

# %%
(np.abs(numeric_test_df.min().min()))
# -2781.450000
# Out:
# 2781.4499999999998

# %%
numeric_train_df = numeric_train_df + (np.abs(numeric_train_df.min().min())) + 1

# %%
numeric_test_df = numeric_test_df + (np.abs(numeric_test_df.min().min())) + 1

# %%
numeric_train_df[numeric_train_df["Temperature"] <= 0]
numeric_train_df[numeric_train_df["MarkDown2"] <= 0]
numeric_train_df[numeric_train_df["MarkDown3"] <= 0]
# Out:
# Empty DataFrame
# Columns: [Size, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment]
# Index: []

# %%
numeric_test_df[numeric_test_df["Temperature"] <= 0]
numeric_test_df[numeric_test_df["MarkDown1"] <= 0]
numeric_test_df[numeric_test_df["MarkDown2"] <= 0]
numeric_test_df[numeric_test_df["MarkDown3"] <= 0]
numeric_test_df[numeric_test_df["MarkDown5"] <= 0]
# Out:
# Empty DataFrame
# Columns: [Size, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment]
# Index: []

# %%
numeric_test_df[numeric_test_df["Fuel_Price"] <= 0]
numeric_test_df[numeric_test_df["Unemployment"] <= 0]
# Out:
# Empty DataFrame
# Columns: [Size, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment]
# Index: []

# %%
numeric_train_log_df = np.log(numeric_train_df)
numeric_test_log_df = np.log(numeric_test_df)

# %%
numeric_train_boxcox_df = pd.DataFrame()
for col in numeric_train_df.columns:
    boxcox_trans_train = st.boxcox(numeric_train_df[col] + 1)[0]
    numeric_train_boxcox_df[col] = boxcox_trans_train

# %%
numeric_test_boxcox_df = pd.DataFrame()
for col in numeric_test_df.columns:
    boxcox_trans_test = st.boxcox(numeric_test_df[col] + 1)[0]
    numeric_test_boxcox_df[col] = boxcox_trans_test
#This creates a "RuntimeWarning", so we need to use np.log instead.

# %%
numeric_test_boxcox_df.head() #boxcox doesn't work here.
# Out:
#            Size   Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0  302687.03781  2.941645e+18         inf   9.610298   0.119711   0.119711
# 1  302687.03781  2.941645e+18         inf   9.610298   0.119711   0.119711
# 2  302687.03781  2.941645e+18         inf   9.610298   0.119711   0.119711
# 3  302687.03781  2.941645e+18         inf   9.610298   0.119711   0.119711
# 4  302687.03781  2.941645e+18         inf   9.610298   0.119711   0.119711
#
#    MarkDown4  MarkDown5       CPI  Unemployment
# 0   0.119711   0.119711  0.119711           inf
# 1   0.119711   0.119711  0.119711           inf
# 2   0.119711   0.119711  0.119711           inf
# 3   0.119711   0.119711  0.119711           inf
# 4   0.119711   0.119711  0.119711           inf

# %%
def empty_count(data, feature):
    empty_mask = data[feature].isnull()
    empty_count = len(data[feature][empty_mask])
    return empty_count

def empty_count_total(data):
    for feature in data.columns:
        empty_count1 = empty_count(data,feature)
        if empty_count1 > 0:
            print(feature, empty_count1)
            
def empty_feature(data):
    list_feature=[]
    for feature in data.columns:
        empty_count1 = empty_count(data,feature)
        if empty_count1 > 0:
            list_feature.append(feature)
    return list_feature

# %%
display(empty_count_total(numeric_train_boxcox_df))
display(empty_count_total(numeric_test_boxcox_df))
# Out:
# None
# None

# %% [markdown]
# ### In general, BoxCox normalized the data better than Log, but we will have to use Log here
# ## Size

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["Size"], ax=ax[0])
sns.distplot(numeric_test_log_df["Size"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Size"], ax=ax[0])
sns.distplot(numeric_train_df["Size"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## Temperature

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["Temperature"], ax=ax[0])
sns.distplot(numeric_test_log_df["Temperature"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Temperature"], ax=ax[0])
sns.distplot(numeric_train_df["Temperature"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## Fuel Price

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["Fuel_Price"], ax=ax[0])
sns.distplot(numeric_test_log_df["Fuel_Price"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Fuel_Price"], ax=ax[0])
sns.distplot(numeric_train_df["Fuel_Price"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## MarkDown 1

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["MarkDown1"], ax=ax[0])
sns.distplot(numeric_test_log_df["MarkDown1"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown1"], ax=ax[0])
sns.distplot(numeric_train_df["MarkDown1"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## MarkDown2

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["MarkDown2"], ax=ax[0])
sns.distplot(numeric_test_log_df["MarkDown2"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown2"], ax=ax[0])
sns.distplot(numeric_train_df["MarkDown2"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## MarkDown 3

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["MarkDown3"], ax=ax[0])
sns.distplot(numeric_test_log_df["MarkDown3"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown3"], ax=ax[0])
sns.distplot(numeric_train_df["MarkDown3"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## Markdown4

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["MarkDown4"], ax=ax[0])
sns.distplot(numeric_test_log_df["MarkDown4"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown4"], ax=ax[0])
sns.distplot(numeric_train_df["MarkDown4"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## Markdown5

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["MarkDown5"], ax=ax[0])
sns.distplot(numeric_test_log_df["MarkDown5"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["MarkDown5"], ax=ax[0])
sns.distplot(numeric_train_df["MarkDown5"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## CPI

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["CPI"], ax=ax[0])
sns.distplot(numeric_test_log_df["CPI"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["CPI"], ax=ax[0])
sns.distplot(numeric_train_df["CPI"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')

# %% [markdown]
# ## Unemployment

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_log_df["Unemployment"], ax=ax[0])
sns.distplot(numeric_test_log_df["Unemployment"], ax=ax[1])

ax[0].set_title("Log Train")
ax[1].set_title("Log Test")
# Out:
# Text(0.5,1,'Log Test')

# %%
_, ax = plt.subplots(1, 2, figsize = (20,5))

sns.distplot(numeric_train_df["Unemployment"], ax=ax[0])
sns.distplot(numeric_train_df["Unemployment"], ax=ax[1])

ax[0].set_title("Original Train")
ax[1].set_title("Original Test")
# Out:
# Text(0.5,1,'Original Test')
